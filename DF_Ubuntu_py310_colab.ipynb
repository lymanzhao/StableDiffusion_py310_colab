# %%
#@title ## 1.1 操作系统环境 { display-mode: "form" }
# !nvidia-smi # 文件/笔记本设置/GPU开启
# !sudo apt-get update
# !sudo apt install build-essential zlib1g-dev libncurses5-dev libgdbm-dev libnss3-dev libssl-dev libreadline-dev libffi-dev wget

# %%
#@title ## 1.2 下载已经编译好的版本，ubuntu 20，Colab环境
# %cd /content
# !wget https://github.com/lymanzhao/DF_Ubuntu_py310_colab/releases/download/1.0/Python-3.10.9.tar.gz
#!rm -rf Python-3.10.10
#!mkdir Python-3.10.10
# !tar -x Python-3.10.9 -zxvf Python-3.10.9.tar.gz

# %%
#@title ## [可选]1.2 Python310源码编译 { display-mode: "form" }
# !wget https://www.python.org/ftp/python/3.10.9/Python-3.10.9.tgz
# !tar -xf Python-3.10.9.tgz
# %cd Python-3.10.9/
# !./configure --enable-optimizations
# !make -j 8
# 压缩源码，上传到github
# %cd /content
# !tar -zcvf Python-3.10.9.tar.gz Python-3.10.9

# %%
#@title ## 1.3 Python310环境配置 { display-mode: "form" }

# %cd /content/Python-3.10.9
# !sudo make altinstall

# !which python3
# !which python3.10
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 1
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/local/bin/python3.10 2
# !sudo update-alternatives --config python3
# 选择2使用Python 310版本
# !python -V
# !curl https://bootstrap.pypa.io/get-pip.py -o get-pip.py
# !python3 get-pip.py

# %%
#@title ## 2.1 下载安装webui { display-mode: "form" }
# %cd /content
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui.git
# %cd /content/stable-diffusion-webui
# !git pull
# !COMMANDLINE_ARGS="--exit" REQS_FILE="requirements.txt" python launch.py

# %%
#@title # 2.2 下载ControlNet和Openpose编辑器
from google.colab import files
import os

# %cd /content/stable-diffusion-webui/extensions
if not os.path.exists("sd-webui-controlnet"):
  # !git clone https://github.com/Mikubill/sd-webui-controlnet.git
  # %cd /content
else:
  # %cd sd-webui-controlnet
  # !git pull
  

# %cd /content/stable-diffusion-webui/extensions
if not os.path.exists("openpose-editor"):
  # !git clone https://github.com/fkunn1326/openpose-editor.git
  # %cd /content
else:
  # %cd openpose-editor
  # !git pull
   

# !cp /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/*.yaml /content/stable-diffusion-webui/models
# %cd "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/models"

# !wget 'https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_canny-fp16.safetensors'
# !wget 'https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_depth-fp16.safetensors'
# !wget 'https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_hed-fp16.safetensors'
# !wget 'https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_mlsd-fp16.safetensors'
# !wget 'https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_normal-fp16.safetensors'
# !wget 'https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_openpose-fp16.safetensors'
# !wget 'https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_scribble-fp16.safetensors'
# !wget 'https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_seg-fp16.safetensors'
# !wget 'https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/t2iadapter_keypose-fp16.safetensors'
# !wget 'https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/t2iadapter_seg-fp16.safetensors'
# !wget 'https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/t2iadapter_sketch-fp16.safetensors'
# !wget 'https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/t2iadapter_depth-fp16.safetensors'

# %%
#@title 3.1 下载模型v1-5-pruned-emaonly.safetensors { display-mode: "form" }
# %cd /content/stable-diffusion-webui

from google.colab import files
import os

if not os.path.exists('/content/stable-diffusion-webui/models/Stable-diffusion/v1-5-pruned-emaonly.safetensors'):
  # !wget https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/v1-5-pruned-emaonly.safetensors

# %%
#@title # 3.2 下载模型chilloumix 以及其他
from google.colab import files
import os
# /content/

if not os.path.exists('/content/stable-diffusion-webui/models/Stable-diffusion/chilloutmix_NiPrunedFp32Fix.safetensors'):
  # !wget https://civitai.com/api/download/models/11745 -O /content/stable-diffusion-webui/models/Stable-diffusion/chilloutmix_NiPrunedFp32Fix.safetensors

# %mkdir -p /content/stable-diffusion-webui/models/Lora/
if not os.path.exists('/content/stable-diffusion-webui/models/Lora/liuyifei_10.safetensors'):
  # !wget https://civitai.com/api/download/models/9969 -O /content/stable-diffusion-webui/models/Lora/liuyifei_10.safetensors

if not os.path.exists('/content/stable-diffusion-webui/models/Lora/gwei_10.safetensors'):
  # !wget https://huggingface.co/Lyman/gwei/resolve/main/gwei_10.safetensors -O /content/stable-diffusion-webui/models/Lora/gwei_10.safetensors

if not os.path.exists('/content/stable-diffusion-webui/models/Lora/elegantHanfuRuqun_v10.safetensors'):
  # !wget https://civitai.com/api/download/models/9470 -O /content/stable-diffusion-webui/models/Lora/elegantHanfuRuqun_v10.safetensors

if not os.path.exists('/content/stable-diffusion-webui/models/Lora/qipao_8.safetensors'):
  # !wget https://civitai.com/api/download/models/15139 -O /content/stable-diffusion-webui/models/Lora/qipao_8.safetensors

# %%
#@title # 3.3 下载风格化Lora
from google.colab import files
import os

# anything 4.5
if not os.path.exists('/content/stable-diffusion-webui/models/Stable-diffusion/anything-v4.5-pruned.safetensors'):
  # !wget https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.5-pruned.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/anything-v4.5-pruned.safetensors

# EasyNegative 
if not os.path.exists('/content/stable-diffusion-webui/embeddings/EasyNegative.safetensors'):
  # !wget https://huggingface.co/datasets/gsdf/EasyNegative/resolve/main/EasyNegative.safetensors -O /content/stable-diffusion-webui/embeddings/EasyNegative.safetensors

# yojiShinkawaStyle
if not os.path.exists('/content/stable-diffusion-webui/models/Lora/yojiShinkawaStyle_offset.safetensors'):
  # !wget https://civitai.com/api/download/models/14533 -O /content/stable-diffusion-webui/models/Lora/yojiShinkawaStyle_offset.safetensors

# makotoShinkaiSubstyles
if not os.path.exists('/content/stable-diffusion-webui/models/Lora/makotoShinkaiSubstyles_offset.safetensors'):
  # !wget https://civitai.com/api/download/models/12610 -O /content/stable-diffusion-webui/models/Lora/makotoShinkaiSubstyles_offset.safetensors

# 墨心
if not os.path.exists('/content/stable-diffusion-webui/models/Lora/Moxin_10.safetensors'):
  # !wget https://civitai.com/api/download/models/14856 -O /content/stable-diffusion-webui/models/Lora/Moxin_10.safetensors

if not os.path.exists('/content/stable-diffusion-webui/models/Lora/Moxin_Shukezouma10.safetensors'):
  # !wget https://civitai.com/api/download/models/16075 -O /content/stable-diffusion-webui/models/Lora/Moxin_Shukezouma10.safetensors  

# studioGhibliStyle_offset.safetensors
if not os.path.exists('/content/stable-diffusion-webui/models/Lora/studioGhibliStyle_offset.safetensors'):
  # !wget https://civitai.com/api/download/models/7657 -O /content/stable-diffusion-webui/models/Lora/studioGhibliStyle_offset.safetensors

# %%
#@title # 4 运行
# %cd /content/stable-diffusion-webui
# !COMMANDLINE_ARGS="--xformers --deepdanbooru --share --gradio-debug --gradio-auth zyl:2023" REQS_FILE="requirements.txt" python launch.py
