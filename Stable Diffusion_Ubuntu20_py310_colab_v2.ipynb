# %%
#@title ## 1.1 操作系统环境,如断开代码,注意是否开启GPU { display-mode: "form" }

#在菜单中依次选择 修改 > 笔记本设置，硬件加速器选项启用 GPU，然后重新执行该代码单元格。也可以在 代码执行程序 > 更改运行时类型，启用 GPU"

from google.colab import runtime
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:

  runtime.unassign()

else:
  print(gpu_info)

#!nvidia-smi # 文件/笔记本设置/GPU开启
# !sudo apt-get update
# !sudo apt install build-essential zlib1g-dev libncurses5-dev libgdbm-dev libnss3-dev libssl-dev libreadline-dev libffi-dev wget
# !sudo apt install aria2

# %%
#@title ## 1.2 下载已编译版 python 3.10.9
# %cd /content
# !wget https://github.com/lymanzhao/StableDiffusion_py310_colab/releases/download/1.0/Python-3.10.9.tar.gz
#!rm -rf Python-3.10.10
#!mkdir Python-3.10.10
# !tar -x Python-3.10.9 -zxvf Python-3.10.9.tar.gz

# %%
#@title ## [可选]1.2 Python310源码编译 { display-mode: "form" }
# !wget https://www.python.org/ftp/python/3.10.9/Python-3.10.9.tgz
# !tar -xf Python-3.10.9.tgz
# %cd Python-3.10.9/
# !./configure --enable-optimizations
# !make -j 8
# # 压缩源码，上传到github
# %cd /content
# !tar -zcvf Python-3.10.9.tar.gz Python-3.10.9

# %%
#@title ## 1.3 Python310环境配置 { display-mode: "form" }

# %cd /content/Python-3.10.9
# !sudo make altinstall

# !which python3
# !which python3.10
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 1
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/local/bin/python3.10 2
#!sudo update-alternatives --config python3
# !sudo update-alternatives  --set python3 /usr/local/bin/python3.10
# 选择2使用Python 310版本
# !python -V
# !curl https://bootstrap.pypa.io/get-pip.py -o get-pip.py
# !python3 get-pip.py

# %%
#@title ## 2.1 下载安装webui { display-mode: "form" }
# %cd /content
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui.git
# %cd /content/stable-diffusion-webui
# !git pull
# !COMMANDLINE_ARGS="--exit" REQS_FILE="requirements.txt" python launch.py

# %%
#@title ## 2.2 下载常用插件{ display-mode: "form" }
# %cd /content/stable-diffusion-webui
# !wget -N https://raw.githubusercontent.com/lymanzhao/StableDiffusion_py310_colab/main/SDextensionsDownload.py
# !mkdir -p /content/stable-diffusion-webui/textual_inversion
# !python SDextensionsDownload.py

# %%
#@title ## 2.3 下载模型{ display-mode: "form" }
# %cd /content/stable-diffusion-webui

# !mkdir -p /content/stable-diffusion-webui/models/Lora
# !wget -N https://raw.githubusercontent.com/lymanzhao/StableDiffusion_py310_colab/main/SDModelDownload.py
# !python SDModelDownload.py

# %%
#@title # 3 运行
# %cd /content/stable-diffusion-webui
# !hostname -I
#!COMMANDLINE_ARGS="--xformers --deepdanbooru --share --gradio-debug --gradio-auth zyl:2023" REQS_FILE="requirements.txt" python launch.py #注意加密登录参数
# !COMMANDLINE_ARGS="--xformers --deepdanbooru --share --gradio-debug" REQS_FILE="requirements.txt" python launch.py

# %%
#@title # 4 下载安装controlnet相关，不适用的情况下可跳过
# %cd /content/stable-diffusion-webui

# !wget -N https://raw.githubusercontent.com/lymanzhao/StableDiffusion_py310_colab/main/SDcontrolnetExtensionsDownload.py
# !python SDcontrolnetExtensionsDownload.py

# %%
#@title # 5 训练

## 安装脚本
# %cd /content/stable-diffusion-webui

# !wget -N https://raw.githubusercontent.com/lymanzhao/StableDiffusion_py310_colab/main/SDTrainingExtensionsDownload.py
# !python SDTrainingExtensionsDownload.py

## 导入图片
#from google.colab import drive
# wget https://drive.google.com/u/0/uc?id=1-0J2bK19otMR4NQD2hwKjN58irTPeWWk&export=download
#drive.mount('/content/gdrive/', force_remount=True)
#!unzip -j -o /content/gdrive/MyDrive/gwei.zip -d /content/gwei/trainimage
